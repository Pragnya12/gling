# %%
#importing libraries
import pandas as pd
import numpy as np
data=pd.read_csv('raw-materials.csv')

# %%
data1=data.fillna(data.mean())

# %%
#print data1
data1
# Out:
#     Sample     size1  size2  size3   density1   density2  density3
# 0   X12558  0.696000  2.690  6.380  41.800000  17.180000  3.900000
# 1   X14728  0.636000  2.300  5.140  38.100000  12.730000  3.890000
# 2   X15468  0.841000  2.850  5.200  37.600000  13.580000  3.980000
# 3   X21364  0.609000  2.130  4.620  34.200000  11.120000  4.020000
# 4   X23671  0.684000  2.160  4.870  36.400000  12.240000  3.920000
# 5   X24055  0.762000  2.810  6.360  38.100000  13.280000  3.890000
# 6   X24905  0.552000  2.340  5.030  41.300000  16.710000  3.860000
# 7   X25917  0.501000  2.170  5.090  37.269231  13.363077  3.939231
# 8   X27871  0.619000  2.110  5.130  37.269231  13.363077  3.939231
# 9   X28690  0.610000  2.100  4.180  35.000000  12.150000  3.860000
# 10  X31385  0.532000  2.090  4.930  37.269231  13.363077  3.939231
# 11  X31813  0.738000  2.290  5.470  37.269231  13.363077  3.939231
# 12  X32807  0.779000  2.620  5.590  37.269231  13.363077  3.939231
# ...

# %%
data2=data.fillna(data.mode())

# %%
#print data2
data2
# Out:
#     Sample  size1  size2  size3  density1  density2  density3
# 0   X12558  0.696   2.69   6.38      41.8     17.18      3.90
# 1   X14728  0.636   2.30   5.14      38.1     12.73      3.89
# 2   X15468  0.841   2.85   5.20      37.6     13.58      3.98
# 3   X21364  0.609   2.13   4.62      34.2     11.12      4.02
# 4   X23671  0.684   2.16   4.87      36.4     12.24      3.92
# 5   X24055  0.762   2.81   6.36      38.1     13.28      3.89
# 6   X24905  0.552   2.34   5.03      41.3     16.71      3.86
# 7   X25917  0.501   2.17   5.09       NaN     12.24       NaN
# 8   X27871  0.619   2.11   5.13       NaN     12.37       NaN
# 9   X28690  0.610   2.10   4.18      35.0     12.15      3.86
# 10  X31385  0.532   2.09   4.93       NaN     12.73       NaN
# 11  X31813  0.738   2.29   5.47       NaN     13.04       NaN
# 12  X32807  0.779   2.62   5.59       NaN     13.14       NaN
# 13  X33943  0.537   2.23   5.41      35.2     11.34      3.99
# ...

# %%
data3=data.fillna(data.median())

# %%
#print data3
data3
# Out:
#     Sample  size1  size2  size3  density1  density2  density3
# 0   X12558  0.696   2.69   6.38      41.8     17.18      3.90
# 1   X14728  0.636   2.30   5.14      38.1     12.73      3.89
# 2   X15468  0.841   2.85   5.20      37.6     13.58      3.98
# 3   X21364  0.609   2.13   4.62      34.2     11.12      4.02
# 4   X23671  0.684   2.16   4.87      36.4     12.24      3.92
# 5   X24055  0.762   2.81   6.36      38.1     13.28      3.89
# 6   X24905  0.552   2.34   5.03      41.3     16.71      3.86
# 7   X25917  0.501   2.17   5.09      37.3     13.21      3.92
# 8   X27871  0.619   2.11   5.13      37.3     13.21      3.92
# 9   X28690  0.610   2.10   4.18      35.0     12.15      3.86
# 10  X31385  0.532   2.09   4.93      37.3     13.21      3.92
# 11  X31813  0.738   2.29   5.47      37.3     13.21      3.92
# 12  X32807  0.779   2.62   5.59      37.3     13.21      3.92
# 13  X33943  0.537   2.23   5.41      35.2     11.34      3.99
# ...
